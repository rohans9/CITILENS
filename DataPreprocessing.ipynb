# %%
# Importing necessary libraries
import pandas as pd
import numpy as np

# %%
# Reading the CSV file into a pandas DataFrame
crime = pd.read_csv("C:\\Users\\Rohan Sahu\\OneDrive\\Desktop\\New folder\\FIR_Details_Data.csv", low_memory=False)

# %%
# Displaying the first few rows of the DataFrame
crime.head()
# Out:
#   District_Name    UnitName      FIRNo  RI  Year  Month  \
# 0      Bagalkot  Amengad PS  0001/2016   1  2016      1
# 1      Bagalkot  Amengad PS  0002/2016   1  2016      1
# 2      Bagalkot  Amengad PS  0003/2016   1  2016      1
# 3      Bagalkot  Amengad PS  0004/2016   1  2016      1
# 4      Bagalkot  Amengad PS  0005/2016   1  2016      1
#
#          Offence_From_Date          Offence_To_Date         FIR_Reg_DateTime  \
# 0  2015-12-27 12:00:00.000  2015-12-27 12:05:00.000  2016-01-05 11:00:00.000
# 1  2016-01-12 17:30:00.000  2016-01-12 17:35:00.000  2016-01-12 19:00:00.000
# 2  2016-01-12 17:45:00.000  2016-01-12 17:50:00.000  2016-01-12 19:30:00.000
# 3  2016-01-14 21:30:00.000  2016-01-14 21:35:00.000  2016-01-15 14:00:00.000
# 4  2016-01-18 15:00:00.000  2016-01-18 15:05:00.000  2016-01-18 19:30:00.000
#
#      FIR_Date  ... VICTIM COUNT Accused Count Arrested Male Arrested Female  \
# 0  05/01/2016  ...            0             1             1               0
# ...

# %%
# Displaying the column names of the DataFrame
crime.columns
# Out:
# Index(['District_Name', 'UnitName', 'FIRNo', 'RI', 'Year', 'Month',
#        'Offence_From_Date', 'Offence_To_Date', 'FIR_Reg_DateTime', 'FIR_Date',
#        'FIR Type', 'FIR_Stage', 'Complaint_Mode', 'CrimeGroup_Name',
#        'CrimeHead_Name', 'Latitude', 'Longitude', 'ActSection', 'IOName',
#        'KGID', 'IOAssigned_Date', 'Internal_IO', 'Place of Offence',
#        'Distance from PS', 'Beat_Name', 'Village_Area_Name', 'Male', 'Female',
#        'Boy', 'Girl', 'Age 0', 'VICTIM COUNT', 'Accused Count',
#        'Arrested Male', 'Arrested Female', 'Arrested Count\tNo.',
#        'Accused_ChargeSheeted Count', 'Conviction Count', 'FIR_ID', 'Unit_ID',
#        'Crime_No'],
#       dtype='object')

# %%
# Selecting specific columns ['Latitude', 'Longitude', 'CrimeGroup_Name'] from the DataFrame
crime = crime[['Latitude', 'Longitude', 'CrimeGroup_Name']]
crime.head()
# Out:
#    Latitude  Longitude                    CrimeGroup_Name
# 0       0.0        0.0                              POCSO
# 1       0.0        0.0          KARNATAKA POLICE ACT 1963
# 2       0.0        0.0          KARNATAKA POLICE ACT 1963
# 3       0.0        0.0  MOTOR VEHICLE ACCIDENTS NON-FATAL
# 4       0.0        0.0      MOTOR VEHICLE ACCIDENTS FATAL

# %%
# Dropping rows with missing values
crime.dropna()
# Out:
#           Latitude  Longitude                    CrimeGroup_Name
# 0         0.000000   0.000000                              POCSO
# 1         0.000000   0.000000          KARNATAKA POLICE ACT 1963
# 2         0.000000   0.000000          KARNATAKA POLICE ACT 1963
# 3         0.000000   0.000000  MOTOR VEHICLE ACCIDENTS NON-FATAL
# 4         0.000000   0.000000      MOTOR VEHICLE ACCIDENTS FATAL
# ...            ...        ...                                ...
# 1694186  16.748633  77.133669                     MISSING PERSON
# 1694187  16.844536  77.021722                              POCSO
# 1694188  16.556974  77.159238                        MOLESTATION
# 1694189  16.772232  77.117018            CRIMES RELATED TO WOMEN
# 1694190  16.800526  77.141569           KIDNAPPING AND ABDUCTION
#
# [1694186 rows x 3 columns]

# %%
# Filtering out rows where both Latitude and Longitude are zero
crime = crime.loc[crime['Latitude'] * crime['Longitude'] != 0]

# %%
# Displaying information about the DataFrame after cleaning operations
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 513027 entries, 610 to 1694190
# Data columns (total 3 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Latitude         513022 non-null  float64
#  1   Longitude        513022 non-null  float64
#  2   CrimeGroup_Name  513027 non-null  object
# dtypes: float64(2), object(1)
# memory usage: 15.7+ MB

# %%
# Randomly sampling 100,000 rows from the DataFrame
crime_df = crime.sample(100000)

# %%
# Displaying information about the sampled DataFrame
crime_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100000 entries, 806829 to 705727
# Data columns (total 3 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Latitude         100000 non-null  float64
#  1   Longitude        100000 non-null  float64
#  2   CrimeGroup_Name  100000 non-null  object
# dtypes: float64(2), object(1)
# memory usage: 3.1+ MB

# %%
crime_df.head()
# Out:
#          Latitude  Longitude    CrimeGroup_Name
# 806829  14.598719  76.711283      CASES OF HURT
# 530925  12.962117  77.571638     MISSING PERSON
# 899321  15.429984  75.432539  ATTEMPT TO MURDER
# 969236  12.265922  75.825952      CASES OF HURT
# 332786  13.004756  77.694535              THEFT

# %%
# Writing the sampled DataFrame to a new CSV file without including the index
crime_df.to_csv('crime_head.csv', index=False)
